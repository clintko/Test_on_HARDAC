# %%
library(rstan)
# Out:
# Error in library(rstan): there is no package called ‘rstan’
# Traceback:
#
# 1. library(rstan)

# %%
library(cmdstanr)
# Out:
# This is cmdstanr version 0.4.0
# - Online documentation and vignettes at mc-stan.org/cmdstanr
# - Use set_cmdstan_path() to set the path to CmdStan
# - Use install_cmdstan() to install CmdStan

# %%
set_cmdstan_path("/data/reddylab/Kuei/exe/cmdstan")
# Out:
# CmdStan path set to: /data/reddylab/Kuei/exe/cmdstan

# %%
read_cmdstan_csv("./ex_toy01/output.csv")
# Out:
# $metadata
# $metadata$stan_version_major
# [1] 2
#
# $metadata$stan_version_minor
# [1] 26
#
# $metadata$stan_version_patch
# [1] 1
#
# $metadata$start_datetime
# [1] "2021-05-27 01:27:53 UTC"
#
# $metadata$method
# [1] "sample"
#
# $metadata$save_warmup
# [1] 0
#
# $metadata$thin
# [1] 1
#
# $metadata$gamma
# [1] 0.05
#
# $metadata$kappa
# [1] 0.75
#
# $metadata$t0
# [1] 10
#
# $metadata$init_buffer
# [1] 75
#
# $metadata$term_buffer
# [1] 50
#
# $metadata$window
# [1] 25
#
# $metadata$algorithm
# [1] "hmc"
#
# $metadata$engine
# [1] "nuts"
#
# $metadata$metric
# [1] "diag_e"
#
# $metadata$stepsize_jitter
# [1] 0
#
# $metadata$id
# [1] 0
#
# $metadata$init
# [1] "./ex_toy01/init.json"
#
# $metadata$seed
# [1] 2996367183
#
# $metadata$refresh
# [1] 100
#
# $metadata$sig_figs
# [1] -1
#
# $metadata$profile_file
# [1] "profile.csv"
#
# $metadata$stanc_version
# [1] "stanc3 888c0f6a"
#
# $metadata$sampler_diagnostics
# [1] "accept_stat__" "stepsize__"    "treedepth__"   "n_leapfrog__"
# ...
